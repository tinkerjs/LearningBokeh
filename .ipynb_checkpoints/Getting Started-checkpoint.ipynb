# %% [markdown]
# # Learning Bokeh
# ## using the tutorials

# %% [markdown]
# ## Do some basic plotting with the default toolset

# %%
from bokeh.plotting import figure, output_file, show, output_notebook

# %%
#prepare some data
x = [1,2,3,4,5]
y = [6,7,2,4,5]

# %%
#output to a static HTML file
output_file('lines.html',title='line plot example')

# %%
#create a new plot with a title and axis labels
p = figure(title='simple line example', x_axis_label='xaxis', y_axis_label='yaxis')

# %%
#add a line renderer with legend and line thickness
p.line(x,y, legend='Temp', line_width=10)

# %%
#show the results
show(p)

# %% [markdown]
# ### The basic steps to creating a plot
# - Prepare some data (in this case plain python lists
# - Tell Bokeh where to generate output (in this case using output_file(), with lines.html as the file name to save as)
# - Call figure() to create a plot with some overall options like title, tools and axes labels.
# - Add renderes (in this case, Figure(p).line) for the data, with visual customizations like colors, legends and widths to the plot.
# - Ask Bokeh to show() or save() the results.

# %% [markdown]
# ### Steps 3 and 4 can be repeated to create more than one plot

# %% [markdown]
# ### Its possible to combine multiple glyphs together on one plot

# %%
#prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static html
#output_file('log_lines.html',title='log line plot example')
#output in notebook
output_notebook()

#create a new plot
p1 = figure(
    tools = "pan, box_zoom, reset, save",
    y_axis_type='log',y_range=[0.001, 10**11], title='Log axis example',
    x_axis_label='sections', y_axis_label='particles'
)

#add some renderers
p1.line(x,x,legend='y=x')
p1.circle(x,x,legend='y=x', fill_color='white', size=8)
p1.line(x, y0, legend='y=x**2', line_width=3)
p1.line(x, y1, legend='y=10**x', line_color='red')
p1.circle(x, y1, legend='y=10**x', fill_color='red', line_color='red', size=6)
p1.line(x, y2, legend='y=10**x**2', line_color='orange', line_dash='4 4')

#show the result
show(p1)

# %% [markdown]
# ### Download the sample data

# %%
#import bokeh.sampledata
#bokeh.sampledata.download()

# %% [markdown]
# ### Vectorized Colors and Sizes

# %%
import numpy as np

# %%
# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5

colors = [
    '#%02x%02x%02x' %(int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)    
]

#output to file
#output_file('color_scatter.html',title='color_scatter example', mode='cdn')
output_notebook()

TOOLS = 'resize, crosshair, pan, wheel_zoom, box_zoom, reset, box_select, lasso_select'

#create a new plot with the tools above
p2 = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

#add a circle renderer with vectorized colors and sizes
p2.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

show(p2)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <div class="plotdiv" id="cace974f-cc1e-4400-bb09-e5515fe728b8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cace974f-cc1e-4400-bb09-e5515fe728b8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cace974f-cc1e-4400-bb09-e5515fe728b8' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"42817f92-809a-4316-9246-4a84f48bf7de": {"version": "0.11.0", "roots": {"root_ids": ["7634c580-21e1-48df-acf0-95ee6f76e9ec"], "references": [{"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "04f42af1-0328-4da6-a6cf-ff25d952b6ab"}, {"attributes": {}, "type": "BasicTicker", "id": "86c6d61a-daa1-4a12-b22d-3145699c7fc7"}, {"attributes": {"line_color": {"value": null}, "fill_color": {"field": "fill_color"}, "fill_alpha": {"value": 0.6}, "radius": {"units": "data", "field": "radius"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "bc67c67a-2e2c-4e07-a57f-c62265a3cd6c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}}, "type": "ResizeTool", "id": "7ff5f023-be2c-49a0-a5c7-2aefa6e44d9b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}, "formatter": {"type": "BasicTickFormatter", "id": "7b43645d-cca5-4b0b-a15c-74d6bf0025c8"}, "ticker": {"type": "BasicTicker", "id": "1167d1a8-f185-43f4-be5e-ab7215fd2b91"}}, "type": "LinearAxis", "id": "dec5ed6e-03a0-4cc0-82d2-8435dce2e704"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "fill_color": {"value": "lightgrey"}, "level": "overlay", "fill_alpha": {"value": 0.5}, "plot": null, "xs_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "ys_units": "screen"}, "type": "PolyAnnotation", "id": "02ea6efd-4dc4-4b8d-8d5a-92e55804d3e3"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "7b43645d-cca5-4b0b-a15c-74d6bf0025c8"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}}, "type": "PanTool", "id": "caed6cef-3100-4231-a29d-6251fa027cfd"}, {"attributes": {"callback": null, "renderers": [{"type": "GlyphRenderer", "id": "b4becc4d-7532-4904-892c-db3469e1ee1b"}], "plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}, "overlay": {"type": "BoxAnnotation", "id": "0a69d905-f258-4a04-842f-88af1df39689"}}, "type": "BoxSelectTool", "id": "dd236225-f470-4e75-bfb2-a4ba9f8554bf"}, {"attributes": {"nonselection_glyph": {"type": "Circle", "id": "e16aeca2-48a8-479b-ba7b-03f8dd8cd031"}, "data_source": {"type": "ColumnDataSource", "id": "69e5afe6-5b13-410d-a0a2-af423852530c"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "bc67c67a-2e2c-4e07-a57f-c62265a3cd6c"}}, "type": "GlyphRenderer", "id": "b4becc4d-7532-4904-892c-db3469e1ee1b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}}, "type": "WheelZoomTool", "id": "bc6ef817-5cda-4c6d-8f8f-3eed32be991c"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "radius": {"units": "data", "field": "radius"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Circle", "id": "e16aeca2-48a8-479b-ba7b-03f8dd8cd031"}, {"attributes": {}, "type": "ToolEvents", "id": "c53b9d65-9e3d-4b1c-886c-92cb24653f68"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}}, "type": "ResetTool", "id": "7d78a5fa-093b-4b24-b145-4df3bf3b573d"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7634c580-21e1-48df-acf0-95ee6f76e9ec"}, "formatter": {"type": "BasicTickFormatter", "id": "9d16d639-f0b2-44f3-bd78-b71149ec39a6"}, "ticker": {"type": "BasicTicker", "id": "86c6d61a-daa1-4a12-b22d-3145699c7fc7"}}, "type": "LinearAxis", "id": "b0ea81c7-ce2f-4f5e-83df-0fa580420070"}, {"attributes": {"plot": {"subt ...

# %% [markdown]
# #### Linked Panning

# %%
import numpy as np
from bokeh.plotting import *

#prepare some data
N = 100
x = np.linspace(0,4*np.pi, N)

y0 = np.sin(x)
y1 = np.cos(x)
y2 = np.sin(x) + np.cos(x)

#set the output
output_notebook()

#create new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color='navy', alpha=0.5)

#new: create a new plot and share both ranges
s2 = figure(width=250, height=250, x_range=s1.x_range, y_range=s1.y_range, title=None)
s2.triangle(x, y1, size=10, color='firebrick', alpha=0.5)

#new: create a new plot and share only one range
s3 = figure(width=250,height=250, x_range=s1.x_range, title=None)
s3.square(x, y2, size=10, color='olive', alpha=0.5)

#new: put the subplots in a grid plot
p = gridplot([[s1,s2,s3]], toolbar_location=None)

#show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <div class="plotdiv" id="11210f9c-4ba2-4dcd-9749-3b8c4933d2eb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("11210f9c-4ba2-4dcd-9749-3b8c4933d2eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '11210f9c-4ba2-4dcd-9749-3b8c4933d2eb' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9f7f8184-01f0-4af7-92d3-a38aa68f5914": {"version": "0.11.0", "roots": {"root_ids": ["2cac3684-e503-46b1-91af-c89fabd8783e"], "references": [{"attributes": {}, "type": "BasicTicker", "id": "2d2729e0-92a6-4b1e-9391-cb0d3416bbb0"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "1322eab4-cbd0-4716-8b52-1507213bf439"}}, "type": "ResetTool", "id": "86a88040-2bf4-4adc-af67-984c3d816344"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ef35ff9b-ed6d-4a7c-94a6-5b85b846a244"}}, "type": "PreviewSaveTool", "id": "51093f84-dae6-46e8-81f9-02e9a3cfc851"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ef35ff9b-ed6d-4a7c-94a6-5b85b846a244"}}, "type": "ResetTool", "id": "5fafbdad-af86-48aa-8d5b-8be64a6d6598"}, {"attributes": {"nonselection_glyph": {"type": "Circle", "id": "caf1b0a6-8ce0-4d1f-be1b-b8c348b99d2e"}, "data_source": {"type": "ColumnDataSource", "id": "fe6fadf2-ced5-4ca6-b4bf-7a4f35c8c553"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "adda0f85-605f-48df-be7f-afab59fb6883"}}, "type": "GlyphRenderer", "id": "47973162-25ba-4c6d-9cce-ad8f8a5270fe"}, {"attributes": {}, "type": "BasicTicker", "id": "44dad760-0e06-48a4-9712-bb23bda80263"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d6cf0a13-0265-4253-894f-d0dd66b1d103"}, "formatter": {"type": "BasicTickFormatter", "id": "4cfd4d94-c91b-4408-9411-15f38860ea66"}, "ticker": {"type": "BasicTicker", "id": "e0aa57f5-1117-48cd-8301-7f3b2120f17a"}}, "type": "LinearAxis", "id": "d7ee319d-aab6-4fe3-aa40-8c9633bee348"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "1322eab4-cbd0-4716-8b52-1507213bf439"}}, "type": "ResizeTool", "id": "c843fefa-fae5-42a0-ba21-f9252c088c0c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "1322eab4-cbd0-4716-8b52-1507213bf439"}, "formatter": {"type": "BasicTickFormatter", "id": "9e6062c1-2186-4d74-b93d-d3aff4b1abb8"}, "ticker": {"type": "BasicTicker", "id": "ae744182-2e42-4d61-9c5a-60e8a2444895"}}, "type": "LinearAxis", "id": "2e07af03-668d-46d7-88c4-50363f2f33e6"}, {"attributes": {"nonselection_glyph": {"type": "Triangle", "id": "ef767ade-642e-44f3-b4a8-812381e45ead"}, "data_source": {"type": "ColumnDataSource", "id": "3e751753-db57-478b-ae85-b65b71a081a8"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Triangle", "id": "a90a477f-9a95-40f2-9d07-c0f0431f0258"}}, "type": "GlyphRenderer", "id": "4ea2bfb8-9b22-44d6-bbc3-3812e3147dca"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "1e733f8a-4f7c-4c59-84da-35bdd977cc2e"}, {"attributes": {}, "type": "ToolEvents", "id": "15c00fdd-9ae6-4a0a-a138-bea84620602a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ef35ff9b-ed6d-4a7c-94a6-5b85b846a244"}, "overlay": {"type": "BoxAnnotation", "id": "80b50061-1879-4a52-83bd-7f925cc910dc"}}, "type": "BoxZoomTool", "id": "22b02cb7-2e7a-4cc2-a719-27c6be446f05"}, {"attributes": {"callback": null, "column_names": ["x", "y"], "data": {"y": [0.0, 0.12659245357374926, 0.2511479871810792, 0.3716624556603276, 0.4861967361004687, 0.5929079290546404, 0.690079011482112, 0.7761464642917568, 0.8497254299495144, 0.9096319953545183, 0.9549022414440739, 0.984807753012208, 0.998867339183008, 0.9968547759519424, 0.9788024462147787, 0.9450008187146685, 0.8959937742913359, 0.8325698546347714, 0.7557495743542583, 0.6667690005162917, 0.5670598638627709, 0.4582265217274105, 0.3420201433256689, 0.2203105327865408, 0.09505604330418244, -0.03172793349806786, -0.15800139597335008, -0.28173255684142984, -0.4009305354066138, -0.5136773915734064, -0.6181589862206053, -0.7126941713788629, -0.7957618405308321, -0.8660254037844388, -0.9223542941045814, -0.9638421585599422, -0.9898214418809327, -0.9998741276738751, -0.9938384644612541, -0.9718115683235417, -0.9341478602651068, -0.881453363447582, -0.8145759520503358, -0.7345917086575332, -0.6427876096865396, -0.540640 ...

# %% [markdown]
# #### linked brushing

# %%
import numpy as np
from bokeh.plotting import *
from bokeh.models import ColumnDataSource

#prepare some data
N = 300
x = np.linspace(0,4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)

#set the output
output_notebook()

#NEW: create a column data sournce for the plots to share
source = ColumnDataSource(data=dict(x=x, y0=y0, y1=y1))

TOOLS = 'pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select'

#create a new plot and add a renderer
left = figure(tools=TOOLS, width=350, height=350, title=None)
left.circle('x','y0',source=source)

#create another new plot and add renderer
right = figure(tools=TOOLS, width=350, height=350, title=None)
right.circle('x','y1', source=source)

#put the subplots in gridplot
p = gridplot([[left, right]])

#show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <div class="plotdiv" id="25a04e26-4ca7-4c71-936c-4c881115f2d2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25a04e26-4ca7-4c71-936c-4c881115f2d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25a04e26-4ca7-4c71-936c-4c881115f2d2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e1637e43-66ae-4feb-885a-5a98fd4394bf": {"version": "0.11.0", "roots": {"root_ids": ["2cac3684-e503-46b1-91af-c89fabd8783e", "0d813615-a021-4367-9c0c-e121cf00e5da", "5d90fabf-f32b-4752-81c2-7858f093336a", "ff30ac9f-d075-409e-91fd-b14a1ed2723c", "bdf4843c-6352-4f39-9698-c4c14d50096d"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "2938f07e-2f8b-47d3-9515-c21b929e5cc5"}, "formatter": {"type": "BasicTickFormatter", "id": "8daf9781-7f0b-4cc3-b933-f87efd6b066c"}, "ticker": {"type": "BasicTicker", "id": "9ddcf9da-95f8-444f-b809-650c019e7c0b"}}, "type": "LinearAxis", "id": "56c34235-0299-451a-82ec-b0be5b704834"}, {"attributes": {}, "type": "BasicTicker", "id": "696cfc9e-6e65-44ed-bc69-f337f410ed08"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "95cf7daf-5ca2-49f2-8642-a55e72b5851f"}}, "type": "ResetTool", "id": "a2628320-768b-4607-9e8e-b9e624f99f8f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d0b191e8-b0bf-4810-894b-7718104875ba"}}, "type": "PanTool", "id": "d78530e9-9f2d-4bbd-94c2-625ecd730a37"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "47ec4d1e-be10-41be-99ad-c958a810f323"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "fill_color": {"value": "lightgrey"}, "level": "overlay", "fill_alpha": {"value": 0.5}, "plot": null, "xs_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "ys_units": "screen"}, "type": "PolyAnnotation", "id": "c30282c0-10db-474f-9e43-091d7cbce357"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d6cf0a13-0265-4253-894f-d0dd66b1d103"}, "formatter": {"type": "BasicTickFormatter", "id": "4cfd4d94-c91b-4408-9411-15f38860ea66"}, "ticker": {"type": "BasicTicker", "id": "e0aa57f5-1117-48cd-8301-7f3b2120f17a"}}, "type": "LinearAxis", "id": "d7ee319d-aab6-4fe3-aa40-8c9633bee348"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "y": {"field": "y1"}}, "type": "Circle", "id": "2a9a490e-7a86-46e2-a493-1524c5b108a1"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "d0b191e8-b0bf-4810-894b-7718104875ba"}}, "type": "WheelZoomTool", "id": "90baaed1-ca63-45f1-8109-25e0c83b9d38"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "1322eab4-cbd0-4716-8b52-1507213bf439"}, "formatter": {"type": "BasicTickFormatter", "id": "9e6062c1-2186-4d74-b93d-d3aff4b1abb8"}, "ticker": {"type": "BasicTicker", "id": "ae744182-2e42-4d61-9c5a-60e8a2444895"}}, "type": "LinearAxis", "id": "2e07af03-668d-46d7-88c4-50363f2f33e6"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "5af0293c-1f85-4416-93c8-570c24ce6dff"}, "title": null, "y_range": {"type": "DataRange1d", "id": "76fe6f8b-3e00-4f01-8696-27be66a4355e"}, "renderers": [{"type": "LinearAxis", "id": "9423b1f3-8cbe-4a6a-9da9-eb7a03d0abba"}, {"type": "Grid", "id": "6e7ce975-fb04-47b6-9ef5-938a821f052f"}, {"type": "LinearAxis", "id": "f9ff9c2f-d0af-4644-b139-f33663f67301"}, {"type": "Grid", "id": "ba58d7c6-85ab-4131-98d0-e1d13e58090b"}, {"type": "BoxAnnotation", "id": "93effe1e-5b34-468a-a196-69deb608ccb4"}, {"type": "BoxAnnotation", "id": "c10b063c-72e9-4743-b1f6-079583f11ee0"}, {"type": "PolyAnnotation", "id": "26ecae79-4039-49a0-9274-60d79532996b"}, {"type": "GlyphRenderer", "id": "71969b75-2c48-4903-b5c2-7182fe8ed411"}], "plot_width": 350, "below": [{"type": "LinearAxis", "id": "9423b1f3-8cbe-4a6a-9da9-eb7a03d0abba"}], "tool_events": {"type": "ToolEvents", "id": "33cf81df-659d-4b1f-9e95-b4d165b7bd26"}, "plot_height": 350, "tools": [{"type": "PanTool", "id": "b5c3a432- ...
